# %%
model = doc2vec.Doc2Vec(vector_size = 300, alpha = 0.025, min_alpha = 0.025, workers = 8, windows = 8)

model.build_vocab(tagged_corpus_list)

# %%
from preprocessor.preprocessor import ArticlePreprocessor

article_preprocessor = ArticlePreprocessor()

# %%
# 4999, 2462, 2393, 2630, 1809
article_preprocessor.raw_data.loc[1809, "Content"]
# Out:
# ' 팬들에게 박수 보내는 세네갈 선수들2022 국제축구연맹FIFA 카타르 월드컵에서 세네갈이 에콰도르를 꺾고 20년 만에 16강에 진출했습니다.세네갈은 카타르 알라이얀의 칼리파 인터내셔널 스타디움에서 열린 조별리그 A조 최종 3차전에서 에콰도르를 2대 1로 물리쳤습니다.2승 1패 승점 6을 기록한 세네갈은 네덜란드2승 1무.승점 7에 이어 조 2위로 16강행 티켓을 거머쥐었습니다.2002 한일 월드컵에서 돌풍을 일으키며 8강까지 올랐던 세네갈은 20년 만에 16강 진출에 성공했습니다.1차전에서 네덜란드에 2대 0으로 졌던 세네갈은 2차전에서 개최국 카타르를 3대 1로 꺾으며 반등했고 조별리그 최종전에서 에콰도르에 승리해 A조 2위로 조별리그를 통과했습니다.세네갈은 득점 없이 맞선 전반 44분 이스마일라 사르의 페널티킥 골로 기선을 잡았습니다.후반 22분 에콰도르의 모이세스 카이세도에게 동점골을 허용했지만 3분 뒤에 터진 칼리두 쿨리발리의 결승골로 짜릿한 승리를 거뒀습니다.비기기만 해도 16강에 갈 수 있었던 에콰도르는 1골 차 아쉬운 패배를 당해 1승 1무 1패 조 3위로 카타르 월드컵 무대에서 퇴장했습니다.사진게티이미지코리아'

# %%
preprocessed_df = article_preprocessor.fit()
# Out:
# >>> 뉴스기사 제목 및 내용의 클렌징 작업이 완료되었습니다.
# >>> 뉴스기사 제목 및 내용의 전처리 작업이 완료되었습니다.
# >>> 결측값을 빈 문자열로 대체하였습니다.

# %%
preprocessed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001 entries, 0 to 10000
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            10001 non-null  int64
#  1   MainCategory  10001 non-null  object
#  2   Title         10001 non-null  object
#  3   Content       10001 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 312.7+ KB

# %%
preprocessed_df.to_csv("./data/test_set.csv", encoding = "utf-8-sig", index = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 preprocessed_df.to_csv("./data/test_set.csv", encoding = "utf-8-sig", index = False)
#
# NameError: name 'preprocessed_df' is not defined

# %%
import pandas as pd
from recommender.content_recommender import *
# Out:
# The kernel failed to start as a dll could not be loaded.
#
# 자세한 내용을 보려면 <a href='https://aka.ms/kernelFailuresDllLoad'>여기</a>를 클릭합니다.

# %%
preprocessed_data = pd.read_csv("./data/test_set.csv", encoding = "utf-8-sig", keep_default_na = False)
preprocessed_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001 entries, 0 to 10000
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            10001 non-null  int64
#  1   MainCategory  10001 non-null  object
#  2   Title         10001 non-null  object
#  3   Content       10001 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 312.7+ KB

# %%
result_df = content_recommender(preprocessed_data)
# Out:
# >>> 1를 계산 중입니다.
# >>> 2를 계산 중입니다.
# >>> 3를 계산 중입니다.
# >>> 4를 계산 중입니다.
# >>> 5를 계산 중입니다.
# >>> 6를 계산 중입니다.
# >>> 7를 계산 중입니다.
# >>> 8를 계산 중입니다.
# >>> 9를 계산 중입니다.
# >>> 10를 계산 중입니다.
# >>> 11를 계산 중입니다.
# >>> 12를 계산 중입니다.
# >>> 13를 계산 중입니다.
# >>> 14를 계산 중입니다.
# >>> 15를 계산 중입니다.
# >>> 16를 계산 중입니다.
# >>> 17를 계산 중입니다.
# >>> 18를 계산 중입니다.
# >>> 19를 계산 중입니다.
# >>> 20를 계산 중입니다.
# >>> 21를 계산 중입니다.
# >>> 22를 계산 중입니다.
# >>> 23를 계산 중입니다.
# >>> 24를 계산 중입니다.
# >>> 25를 계산 중입니다.
# >>> 26를 계산 중입니다.
# >>> 27를 계산 중입니다.
# >>> 28를 계산 중입니다.
# >>> 29를 계산 중입니다.
# >>> 30를 계산 중입니다.
# >>> 31를 계산 중입니다.
# >>> 32를 계산 중입니다.
# >>> 33를 계산 중입니다.
# >>> 34를 계산 중입니다.
# >>> 35를 계산 중입니다.
# >>> 36를 계산 중입니다.
# >>> 37를 계산 중입니다.
# >>> 38를 계산 중입니다.
# >>> 39를 계산 중입니다.
# >>> 40를 계산 중입니다.
# >>> 41를 계산 중입니다.
# >>> 42를 계산 중입니다.
# >>> 43를 계산 중입니다.
# >>> 44를 계산 중입니다.
# >>> 45를 계산 중입니다.
# >>> 46를 계산 중입니다.
# >>> 47를 계산 중입니다.
# >>> 48를 계산 중입니다.
# >>> 49를 계산 중입니다.
# >>> 50를 계산 중입니다.
# >>> 51를 계산 중입니다.
# >>> 52를 계산 중입니다.
# >>> 53를 계산 중입니다.
# ...

# %%
result_df

# %%
result_df = pd.to_csv("./data/test_set.csv", encoding = "utf-8-sig", index = False)

# %%
doc2vec_list = doc2vec_data_maker(doc2vec_data)
len(doc2vec_list)
# Out:
# 10001

# %%
tagged_doc2vec_list = doc2vec_data_maker(doc2vec_data, tagged_document = True)
len(tagged_doc2vec_list)
# Out:
# 10001

# %%
doc2vec_list[1][0][0] = id
# Out:
# 2

# %%
doc2vec_model_maker(tagged_doc2vec_list)

# %%
model = Doc2Vec.load("./data/newflix_content_model.doc2vec")

# %%
len(model.dv)
# Out:
# 10001

# %%
# 코사인 유사도 점수를 담을 리스트 scores 초기화
scores = []

user = model.dv["5000"]

# for 반복문을 사용해
for tags, doc in doc2vec_list:
    trained_doc_vec = model.dv[tags[0]]
    scores.append(cosine_similarity(user.reshape(-1, 128), trained_doc_vec.reshape(-1, 128)))

len(scores)
# Out:
# 10001

# %%
scores = np.array(scores).reshape(-1)
scores
# Out:
# array([-0.00841444,  0.14863004,  0.15427822, ...,  0.37792987,
#         0.17185314,  0.18208483], dtype=float32)

# %%
best_scores = np.argsort(-scores)[: 5]
best_scores
# Out:
# array([4999, 2462, 2393, 2630, 1809], dtype=int64)

# %%
scores = np.array(scores).reshape(-1)
scores = np.argsort(-scores)[:5]

# %%
for num in range(1, 10002):
    print(type(model.dv[str(num)]))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# ...

# %%
.iloc[4999]

# %%
import numpy as np

annyong = (np.array([1, 2, 3, 4, 5]) + 1).tolist()

annyong
# Out:
# [2, 3, 4, 5, 6]
